# %% [markdown]
# <a href="https://colab.research.google.com/github/alexnelson14/AI-Thoughts/blob/main/my_thoughts_on_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ## Things I want to do with AI
#
#           * Have fun
#           * Take over the world
